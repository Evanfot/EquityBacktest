# %% [markdown]
# # Backtester
# This script performs a backtest with the following details:
#
# #### Alpha
# - Sum of 12m-1m momentum and 5 day mean reversion
# - The factors are calculated to be sector-neutral and then converted to Z-scores, so are combined by summing (no correlation between factors is considered for this exercise)
#
# #### Risk
# - A PCA risk model is trained on the previous five years of data
#
# #### Transaction costs
# - Assumed at 75bp which is optimistic for the early years, but pessimistic for later years, so should balance out
#
# #### Optimiser
# - The StrictFactorOptimiser class is used which finds weights that minimise the L1-norm vs the combined alpha
#
# #### Output
# - A pickle object that ends in "backest.pkl" is output to the desired location which can be read by the backtester.py script for further analysis

# %%
# %% Imports

import sys

sys.path.append("..")
import pandas as pd
import cvxpy as cp
import numpy as np
import datetime as dt
from matplotlib import pyplot as plt
import yaml

from zipline import run_algorithm
from zipline.api import (
    attach_pipeline,
    record,
    order_target_percent,
    order_target,
    symbol,
    schedule_function,
    date_rules,
    time_rules,
    pipeline_output,
)
from zipline.pipeline.domain import ZA_EQUITIES
from six import viewkeys

from data.sector import dict_asset_sector, dict_sector_int, create_sector
from data.pricing import (
    ingest_function,
)
from optimisers.strict_factor_optimiser import OptimalHoldingsStrictFactor
from optimisers.markowitz_optimiser import OptimalHoldings
from alpha_models.alphas import (
    momentum_sector_neutral,
    mean_reversion_5day_sector_neutral,
)
from risk_models.statistical_risk_model import (
    fit_pca,
    factor_betas,
    factor_returns,
    factor_cov_matrix,
    idiosyncratic_var_matrix,
    idiosyncratic_var_vector,
)

from optimisers.strict_factor_optimiser import OptimalHoldingsStrictFactor
from zipline.pipeline import Pipeline
from zipline.finance import commission, slippage
from zipline.pipeline.factors import AverageDollarVolume


from zipline.data import bundles
from zipline.utils.calendar_utils import get_calendar

import pyfolio as pf

# %%
# %% Read config

with open("../config.yml", "r") as file:
    settings = yaml.safe_load(file)

EOD_BUNDLE_NAME = settings["bundles"]["bundle_name"]
path = settings["paths"]["output_path"]
calendar_code = settings["bundles"]["calendar_code"]
start = pd.Timestamp(settings["backtest"]["start_date"])
end = pd.Timestamp(settings["backtest"]["end_date"])
starting_cap = settings["backtest"]["starting_capital"]
run_time = dt.datetime.now().strftime("%Y%m%d_%H%M")


def create_output_path(
    file_name: str, path: str = path, run_time: str = run_time
) -> str:
    return "".join([path, run_time, "_", file_name])


domain_za = ZA_EQUITIES
calendar = get_calendar(calendar_code)


ingest_func = ingest_function(EOD_BUNDLE_NAME)
bundles.register(EOD_BUNDLE_NAME, ingest_func)
bundle_data = bundles.load(EOD_BUNDLE_NAME)


sector_tickers = bundle_data.asset_finder.retrieve_all(bundle_data.asset_finder.sids)
sector, ticker_sector = create_sector(
    sector_tickers, dict_asset_sector, dict_sector_int
)

# %%
# %%

def make_pipeline():
    universe = AverageDollarVolume(window_length=120).top(100)
    momentum_sector_neutral_1yr = momentum_sector_neutral(251, universe, sector)
    momentum_sector_neutral_1m = momentum_sector_neutral(19, universe, sector)
    mean_reversion_5_day_sector_neutral = mean_reversion_5day_sector_neutral(
        5, universe, sector
    )

    return Pipeline(
        columns={
            "universe": universe,
            "momentum_sector_neutral_1y": momentum_sector_neutral_1yr,
            "momentum_sector_neutral_1m": momentum_sector_neutral_1m,
            "Mean_Reversion_5Day_Sector_Neutral": mean_reversion_5_day_sector_neutral,
        },
        domain=domain_za,
    )


def initialize(context):
    attach_pipeline(make_pipeline(), "my_pipeline")
    # Rebalance each day.  In daily mode, this is equivalent to putting
    # `rebalance` in our handle_data, but in minute mode, it's equivalent to
    # running at the start of the day each day.
    schedule_function(
        rebalance, date_rule=date_rules.every_day(), time_rule=time_rules.market_close()
    )

    # Explicitly set the commission/slippage to the "old" value until we can
    # rebuild example data.
    context.set_commission(commission.PerShare(cost=0.0075, min_trade_cost=1))
    context.set_slippage(slippage.VolumeShareSlippage())


def before_trading_start(context, data):
    """
    Called every day before market open.
    """


def calculate_risk(Close):
    five_year_returns = Close.pct_change()[1:].fillna(0)
    num_factor_exposures = 4
    pca = fit_pca(five_year_returns, num_factor_exposures, "full")
    risk_model = {}

    risk_model["factor_betas"] = factor_betas(
        pca, five_year_returns.columns.values, np.arange(num_factor_exposures)
    )

    risk_model["factor_returns"] = factor_returns(
        pca, five_year_returns, five_year_returns.index, np.arange(num_factor_exposures)
    )

    ann_factor = 252
    risk_model["factor_cov_matrix"] = pd.DataFrame(
        factor_cov_matrix(risk_model["factor_returns"], ann_factor)
    )
    risk_model["idiosyncratic_var_matrix"] = idiosyncratic_var_matrix(
        five_year_returns,
        risk_model["factor_returns"],
        risk_model["factor_betas"],
        ann_factor,
    )
    risk_model["idiosyncratic_var_vector"] = idiosyncratic_var_vector(
        five_year_returns, risk_model["idiosyncratic_var_matrix"]
    )
    return risk_model


def calculate_optimal(pipeline, risk_model: dict):
    alpha_vector = pipeline

    optimal_weights = OptimalHoldingsStrictFactor(
        weights_max=0.1,
        weights_min=-0.1,
        risk_cap=0.9,
        factor_max=0.2,
        factor_min=-0.2,
    ).find(
        alpha_vector.fillna(0),
        risk_model["factor_betas"],
        risk_model["factor_cov_matrix"],
        risk_model["idiosyncratic_var_vector"],
    )
    return optimal_weights


def rebalance(context, data):
    print(context.datetime)
    if len(pipeline_output("my_pipeline")) != 0:
        context.output = pipeline_output("my_pipeline")
        pipeline_data = context.output.copy(deep=True)
        pipeline_data.loc[pipeline_data["universe"], ("alpha")] = (
            pipeline_data["momentum_sector_neutral_1y"]
            .subtract(pipeline_data["momentum_sector_neutral_1m"])
            .add(pipeline_data["Mean_Reversion_5Day_Sector_Neutral"] * 0.5)
        )
        pipeline_data = pipeline_data[pipeline_data["universe"]]
        all_assets = pipeline_data.index
        hist = data.history(all_assets, "close", 1250, "1d").dropna(how="all")
        risk_model = calculate_risk(hist)
        optimal_weights = calculate_optimal(pipeline_data[["alpha"]], risk_model)
        record(universe_size=len(all_assets))

        for asset in optimal_weights.index:
            if asset not in context.get_open_orders():
                order_target_percent(asset, optimal_weights.loc[asset].item())

        # Remove any assets that should no longer be in our portfolio.
        positions = context.portfolio.positions
        for asset in viewkeys(positions) - set(optimal_weights.index):
            # This will fail if the asset was removed from our portfolio because it
            # was delisted.
            print("---".join([asset.symbol, "no longer in universe"]))
            if data.can_trade(asset):
                if asset not in context.get_open_orders():
                    order_target(asset, 0)
    else:
        print("No pipeline skipping day")

# %%
# %%

## PricingLoader packages
from zipline.assets._assets import Equity  # Required for EquityPricing
from zipline.pipeline.data import EquityPricing
from zipline.data.fx import ExplodingFXRateReader
from zipline.pipeline.loaders import USEquityPricingLoader, EquityPricingLoader


class PricingLoader(object):
    def __init__(self, bundle_data):
        self.loader = EquityPricingLoader(
            bundle_data.equity_daily_bar_reader,
            bundle_data.adjustment_reader,
            ExplodingFXRateReader(),
        )

    def get_loader(self, column):
        # TODO: Fix exception handling below
        # if column not in EquityPricing.columns:
        # raise Exception('Column not in EquityPricing')
        return self.loader

    def get(self, column):
        # if column not in EquityPricing.columns:
        # raise Exception('Column not in EquityPricing')
        return self.loader


pricing_loader = PricingLoader(bundle_data)

result = run_algorithm(
    start=start,  # Set start
    end=end,  # Set end
    initialize=initialize,  # Define startup function
    capital_base=starting_cap,  # Set initial capital
    data_frequency="daily",  # Set data frequency
    bundle=EOD_BUNDLE_NAME,
    trading_calendar=calendar,
    custom_loader=pricing_loader,
)

result.to_pickle(create_output_path("backtest.pkl"))
print("Ready to analyze result")
# Out:
# /Users/evanfotopoulos/.zipline/extension.py:9: UserWarning: Overwriting bundle with name 'ZAEQ'
#   register(
# 2002-01-07 15:00:00+00:00
# 2002-01-08 15:00:00+00:00
# 2002-01-09 15:00:00+00:00
# 2002-01-10 15:00:00+00:00
# PMN---no longer in universe
# 2002-01-11 15:00:00+00:00
# SNT---no longer in universe
# 2002-01-14 15:00:00+00:00
# 2002-01-15 15:00:00+00:00
# 2002-01-16 15:00:00+00:00
# SNT---no longer in universe
# 2002-01-17 15:00:00+00:00
# SNT---no longer in universe
# TIW---no longer in universe
# 2002-01-18 15:00:00+00:00
# SNT---no longer in universe
# 2002-01-21 15:00:00+00:00
# SNT---no longer in universe
# 2002-01-22 15:00:00+00:00
# 2002-01-23 15:00:00+00:00
# AFR---no longer in universe
# 2002-01-24 15:00:00+00:00
# 2002-01-25 15:00:00+00:00
# 2002-01-28 15:00:00+00:00
# 2002-01-29 15:00:00+00:00
# 2002-01-30 15:00:00+00:00
# 2002-01-31 15:00:00+00:00
# 2002-02-01 15:00:00+00:00
# 2002-02-04 15:00:00+00:00
# 2002-02-05 15:00:00+00:00
# CAT---no longer in universe
# 2002-02-06 15:00:00+00:00
# CAT---no longer in universe
# GBL---no longer in universe
# 2002-02-07 15:00:00+00:00
# AFR---no longer in universe
# GBL---no longer in universe
# 2002-02-08 15:00:00+00:00
# APA---no longer in universe
# 2002-02-11 15:00:00+00:00
# 2002-02-12 15:00:00+00:00
# TDH---no longer in universe
# 2002-02-13 15:00:00+00:00
# TDH---no longer in universe
# 2002-02-14 15:00:00+00:00
# TDH---no longer in universe
# 2002-02-15 15:00:00+00:00
# UNF---no longer in universe
# SIS---no longer in universe
# 2002-02-18 15:00:00+00:00
# UNF---no longer in universe
# SIS---no longer in universe
# 2002-02-19 15:00:00+00:00
# UNF---no longer in universe
# 2002-02-20 15:00:00+00:00
# UNF---no longer in universe
# 2002-02-21 15:00:00+00:00
# UNF---no longer in universe
# TDH---no longer in universe
# 2002-02-22 15:00:00+00:00
# DSY---no longer in universe
# UNF---no longer in universe
# TDH---no longer in universe
# 2002-02-25 15:00:00+00:00
# DSY---no longer in universe
# UNF---no longer in universe
# 2002-02-26 15:00:00+00:00
# UNF---no longer in universe
# 2002-02-27 15:00:00+00:00
# AFR---no longer in universe
# UNF---no longer in universe
# 2002-02-28 15:00:00+00:00
# UNF---no longer in universe
# APA---no longer in universe
# 2002-03-01 15:00:00+00:00
# UNF---no longer in universe
# APA---no longer in universe
# 2002-03-04 15:00:00+00:00
# UNF---no longer in universe
# 2002-03-05 15:00:00+00:00
# UNF---no longer in universe
# 2002-03-06 15:00:00+00:00
# AFR---no longer in universe
# UNF---no longer in universe
# 2002-03-07 15:00:00+00:00
# UNF---no longer in universe
# 2002-03-08 15:00:00+00:00
# 2002-03-11 15:00:00+00:00
# WLN---no longer in universe
# 2002-03-12 15:00:00+00:00
# WLN---no longer in universe
# 2002-03-13 15:00:00+00:00
# TIW---no longer in universe
# GNK---no longer in universe
# 2002-03-14 15:00:00+00:00
# TIW---no longer in universe
# GNK---no longer in universe
# 2002-03-15 15:00:00+00:00
# TIW---no longer in universe
# APA---no longer in universe
# GNK---no longer in universe
# 2002-03-18 15:00:00+00:00
# GNK---no longer in universe
# 2002-03-19 15:00:00+00:00
# TDH---no longer in universe
# GNK---no longer in universe
# 2002-03-20 15:00:00+00:00
# TDH---no longer in universe
# APA---no longer in universe
# GNK---no longer in universe
# 2002-03-22 15:00:00+00:00
# TDH---no longer in universe
# GNK---no longer in universe
# 2002-03-25 15:00:00+00:00
# TDH---no longer in universe
# GNK---no longer in universe
# 2002-03-26 15:00:00+00:00
# TDH---no longer in universe
# 2002-03-27 15:00:00+00:00
# USV---no longer in universe
# 2002-03-28 15:00:00+00:00
# 2002-04-02 15:00:00+00:00
# 2002-04-03 15:00:00+00:00
# 2002-04-04 15:00:00+00:00
# APA---no longer in universe
# 2002-04-05 15:00:00+00:00
# 2002-04-08 15:00:00+00:00
# FDS---no longer in universe
# 2002-04-09 15:00:00+00:00
# FDS---no longer in universe
# 2002-04-10 15:00:00+00:00
# FDS---no longer in universe
# HCI---no longer in universe
# 2002-04-11 15:00:00+00:00
# FDS---no longer in universe
# HCI---no longer in universe
# 2002-04-12 15:00:00+00:00
# FDS---no longer in universe
# HCI---no longer in universe
# 2002-04-15 15:00:00+00:00
# FDS---no longer in universe
# 2002-04-16 15:00:00+00:00
# FDS---no longer in universe
# PMN---no longer in universe
# 2002-04-17 15:00:00+00:00
# FDS---no longer in universe
# APA---no longer in universe
# PMN---no longer in universe
# 2002-04-18 15:00:00+00:00
# FDS---no longer in universe
# PMN---no longer in universe
# 2002-04-19 15:00:00+00:00
# FDS---no longer in universe
# MRP---no longer in universe
# 2002-04-22 15:00:00+00:00
# FDS---no longer in universe
# PMN---no longer in universe
# 2002-04-23 15:00:00+00:00
# FDS---no longer in universe
# CAT---no longer in universe
# PMN---no longer in universe
# 2002-04-24 15:00:00+00:00
# FDS---no longer in universe
# CAT---no longer in universe
# MRP---no longer in universe
# 2002-04-25 15:00:00+00:00
# FDS---no longer in universe
# CAT---no longer in universe
# 2002-04-26 15:00:00+00:00
# FDS---no longer in universe
# CAT---no longer in universe
# 2002-04-29 15:00:00+00:00
# FDS---no longer in universe
# CAT---no longer in universe
# 2002-04-30 15:00:00+00:00
# CAT---no longer in universe
# HCI---no longer in universe
# 2002-05-02 15:00:00+00:00
# CAT---no longer in universe
# HCI---no longer in universe
# 2002-05-03 15:00:00+00:00
# CAT---no longer in universe
# HCI---no longer in universe
# 2002-05-06 15:00:00+00:00
# DSY---no longer in universe
# CAT---no longer in universe
# HCI---no longer in universe
# 2002-05-07 15:00:00+00:00
# DSY---no longer in universe
# CAT---no longer in universe
# 2002-05-08 15:00:00+00:00
# DSY---no longer in universe
# CAT---no longer in universe
# 2002-05-09 15:00:00+00:00
# CAT---no longer in universe
# 2002-05-10 15:00:00+00:00
# CAT---no longer in universe
# PMN---no longer in universe
# 2002-05-13 15:00:00+00:00
# CAT---no longer in universe
# PMN---no longer in universe
# 2002-05-14 15:00:00+00:00
# CAT---no longer in universe
# PMN---no longer in universe
# 2002-05-15 15:00:00+00:00
# CAT---no longer in universe
# PMN---no longer in universe
# SLU---no longer in universe
# 2002-05-16 15:00:00+00:00
# DSY---no longer in universe
# CAT---no longer in universe
# SLU---no longer in universe
# 2002-05-17 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# PMN---no longer in universe
# SLU---no longer in universe
# 2002-05-20 15:00:00+00:00
# DSY---no longer in universe
# SBO---no longer in universe
# CAT---no longer in universe
# SLU---no longer in universe
# 2002-05-21 15:00:00+00:00
# DSY---no longer in universe
# SBO---no longer in universe
# CAT---no longer in universe
# SLU---no longer in universe
# 2002-05-22 15:00:00+00:00
# DSY---no longer in universe
# SBO---no longer in universe
# CAT---no longer in universe
# SLU---no longer in universe
# 2002-05-23 15:00:00+00:00
# JNC---no longer in universe
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-05-24 15:00:00+00:00
# DSY---no longer in universe
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-05-27 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# PMN---no longer in universe
# 2002-05-28 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-05-29 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# APA---no longer in universe
# 2002-05-30 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-05-31 15:00:00+00:00
# JNC---no longer in universe
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-03 15:00:00+00:00
# JNC---no longer in universe
# SBO---no longer in universe
# CAT---no longer in universe
# APA---no longer in universe
# 2002-06-04 15:00:00+00:00
# DSY---no longer in universe
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-05 15:00:00+00:00
# DSY---no longer in universe
# SBO---no longer in universe
# CAT---no longer in universe
# APA---no longer in universe
# 2002-06-06 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-07 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-10 15:00:00+00:00
# JNC---no longer in universe
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-11 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-12 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-13 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-14 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-18 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-19 15:00:00+00:00
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-20 15:00:00+00:00
# MFL---no longer in universe
# SBO---no longer in universe
# CAT---no longer in universe
# 2002-06-21 15:00:00+00:00
# SBO---no longer in universe
# APA---no longer in universe
# 2002-06-24 15:00:00+00:00
# SBO---no longer in universe
# 2002-06-25 15:00:00+00:00
# SBO---no longer in universe
# 2002-06-26 15:00:00+00:00
# MFL---no longer in universe
# SBO---no longer in universe
# 2002-06-27 15:00:00+00:00
# MFL---no longer in universe
# SBO---no longer in universe
# 2002-06-28 15:00:00+00:00
# USV---no longer in universe
# MFL---no longer in universe
# SBO---no longer in universe
# 2002-07-01 15:00:00+00:00
# MFL---no longer in universe
# WLN---no longer in universe
# SBO---no longer in universe
# 2002-07-02 15:00:00+00:00
# WLN---no longer in universe
# SBO---no longer in universe
# 2002-07-03 15:00:00+00:00
# WLN---no longer in universe
# SBO---no longer in universe
# 2002-07-04 15:00:00+00:00
# WLN---no longer in universe
# SBO---no longer in universe
# BOE---no longer in universe
# 2002-07-05 15:00:00+00:00
# WLN---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2002-07-08 15:00:00+00:00
# JCG---no longer in universe
# WLN---no longer in universe
# SBO---no longer in universe
# 2002-07-09 15:00:00+00:00
# WLN---no longer in universe
# SBO---no longer in universe
# 2002-07-10 15:00:00+00:00
# SBO---no longer in universe
# 2002-07-11 15:00:00+00:00
# SBO---no longer in universe
# 2002-07-12 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2002-07-15 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# GLT---no longer in universe
# 2002-07-16 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# GLT---no longer in universe
# 2002-07-17 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2002-07-18 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2002-07-19 15:00:00+00:00
# AFR---no longer in universe
# SBO---no longer in universe
# 2002-07-22 15:00:00+00:00
# AFR---no longer in universe
# SBO---no longer in universe
# 2002-07-23 15:00:00+00:00
# SBO---no longer in universe
# 2002-07-24 15:00:00+00:00
# SBO---no longer in universe
# 2002-07-25 15:00:00+00:00
# SBO---no longer in universe
# 2002-07-26 15:00:00+00:00
# SBO---no longer in universe
# 2002-07-29 15:00:00+00:00
# PON---no longer in universe
# SBO---no longer in universe
# 2002-07-30 15:00:00+00:00
# AFR---no longer in universe
# PON---no longer in universe
# SBO---no longer in universe
# 2002-07-31 15:00:00+00:00
# AFR---no longer in universe
# PON---no longer in universe
# SBO---no longer in universe
# 2002-08-01 15:00:00+00:00
# AFR---no longer in universe
# PON---no longer in universe
# SBO---no longer in universe
# 2002-08-02 15:00:00+00:00
# PON---no longer in universe
# SBO---no longer in universe
# 2002-08-05 15:00:00+00:00
# PPC---no longer in universe
# PON---no longer in universe
# SBO---no longer in universe
# 2002-08-06 15:00:00+00:00
# PPC---no longer in universe
# PON---no longer in universe
# SBO---no longer in universe
# 2002-08-07 15:00:00+00:00
# PPC---no longer in universe
# PON---no longer in universe
# SBO---no longer in universe
# 2002-08-08 15:00:00+00:00
# SBO---no longer in universe
# 2002-08-12 15:00:00+00:00
# AFR---no longer in universe
# SBO---no longer in universe
# 2002-08-13 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2002-08-14 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2002-08-15 15:00:00+00:00
# SBO---no longer in universe
# 2002-08-16 15:00:00+00:00
# SBO---no longer in universe
# 2002-08-19 15:00:00+00:00
# MLB---no longer in universe
# SBO---no longer in universe
# 2002-08-20 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2002-08-21 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2002-08-22 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2002-08-23 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2002-08-26 15:00:00+00:00
# MFL---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# GBL---no longer in universe
# 2002-08-27 15:00:00+00:00
# MFL---no longer in universe
# SBO---no longer in universe
# 2002-08-28 15:00:00+00:00
# MFL---no longer in universe
# SBO---no longer in universe
# 2002-08-29 15:00:00+00:00
# JNC---no longer in universe
# SBO---no longer in universe
# 2002-08-30 15:00:00+00:00
# JNC---no longer in universe
# SBO---no longer in universe
# 2002-09-02 15:00:00+00:00
# SBO---no longer in universe
# 2002-09-03 15:00:00+00:00
# SBO---no longer in universe
# 2002-09-04 15:00:00+00:00
# SBO---no longer in universe
# 2002-09-05 15:00:00+00:00
# SBO---no longer in universe
# 2002-09-06 15:00:00+00:00
# SBO---no longer in universe
# 2002-09-09 15:00:00+00:00
# SBO---no longer in universe
# 2002-09-10 15:00:00+00:00
# DSY---no longer in universe
# SBO---no longer in universe
# 2002-09-11 15:00:00+00:00
# SBO---no longer in universe
# 2002-09-12 15:00:00+00:00
# JNC---no longer in universe
# SBO---no longer in universe
# 2002-09-13 15:00:00+00:00
# JNC---no longer in universe
# SBO---no longer in universe
# 2002-09-16 15:00:00+00:00
# SBO---no longer in universe
# 2002-09-17 15:00:00+00:00
# SBO---no longer in universe
# 2002-09-18 15:00:00+00:00
# GIJ---no longer in universe
# SBO---no longer in universe
# 2002-09-19 15:00:00+00:00
# GIJ---no longer in universe
# SBO---no longer in universe
# 2002-09-20 15:00:00+00:00
# GIJ---no longer in universe
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-09-23 15:00:00+00:00
# GIJ---no longer in universe
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-09-25 15:00:00+00:00
# GIJ---no longer in universe
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-09-26 15:00:00+00:00
# GIJ---no longer in universe
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-09-27 15:00:00+00:00
# GIJ---no longer in universe
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-09-30 15:00:00+00:00
# GIJ---no longer in universe
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-10-01 15:00:00+00:00
# GIJ---no longer in universe
# SBO---no longer in universe
# UTR---no longer in universe
# CRN---no longer in universe
# 2002-10-02 15:00:00+00:00
# GIJ---no longer in universe
# SBO---no longer in universe
# UTR---no longer in universe
# CRN---no longer in universe
# 2002-10-03 15:00:00+00:00
# GIJ---no longer in universe
# SBO---no longer in universe
# UTR---no longer in universe
# CRN---no longer in universe
# 2002-10-04 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# UTR---no longer in universe
# 2002-10-07 15:00:00+00:00
# SBO---no longer in universe
# UTR---no longer in universe
# 2002-10-08 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# UTR---no longer in universe
# 2002-10-09 15:00:00+00:00
# SBO---no longer in universe
# UTR---no longer in universe
# 2002-10-10 15:00:00+00:00
# AEN---no longer in universe
# SBO---no longer in universe
# UTR---no longer in universe
# 2002-10-11 15:00:00+00:00
# AEN---no longer in universe
# SBO---no longer in universe
# UTR---no longer in universe
# 2002-10-14 15:00:00+00:00
# SBO---no longer in universe
# UTR---no longer in universe
# NIB---no longer in universe
# 2002-10-15 15:00:00+00:00
# SBO---no longer in universe
# UTR---no longer in universe
# 2002-10-16 15:00:00+00:00
# SBO---no longer in universe
# UTR---no longer in universe
# 2002-10-17 15:00:00+00:00
# MDC---no longer in universe
# SBO---no longer in universe
# 2002-10-18 15:00:00+00:00
# BDS---no longer in universe
# SBO---no longer in universe
# 2002-10-21 15:00:00+00:00
# BDS---no longer in universe
# PPC---no longer in universe
# SBO---no longer in universe
# 2002-10-22 15:00:00+00:00
# BDS---no longer in universe
# PPC---no longer in universe
# SBO---no longer in universe
# 2002-10-23 15:00:00+00:00
# BDS---no longer in universe
# PPC---no longer in universe
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-10-24 15:00:00+00:00
# PPC---no longer in universe
# SBO---no longer in universe
# MBT---no longer in universe
# 2002-10-25 15:00:00+00:00
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-10-28 15:00:00+00:00
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-10-29 15:00:00+00:00
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-10-30 15:00:00+00:00
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-10-31 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# CRN---no longer in universe
# 2002-11-01 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# 2002-11-04 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# 2002-11-05 15:00:00+00:00
# SNT---no longer in universe
# SBO---no longer in universe
# TDH---no longer in universe
# 2002-11-06 15:00:00+00:00
# SBO---no longer in universe
# GNK---no longer in universe
# CRN---no longer in universe
# 2002-11-07 15:00:00+00:00
# SBO---no longer in universe
# GNK---no longer in universe
# CRN---no longer in universe
# 2002-11-08 15:00:00+00:00
# SNT---no longer in universe
# SBO---no longer in universe
# GNK---no longer in universe
# 2002-11-11 15:00:00+00:00
# TIW---no longer in universe
# SBO---no longer in universe
# GNK---no longer in universe
# 2002-11-12 15:00:00+00:00
# SBO---no longer in universe
# GNK---no longer in universe
# 2002-11-13 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# CHE---no longer in universe
# GNK---no longer in universe
# 2002-11-14 15:00:00+00:00
# SBO---no longer in universe
# CHE---no longer in universe
# 2002-11-15 15:00:00+00:00
# TIW---no longer in universe
# SBO---no longer in universe
# CHE---no longer in universe
# 2002-11-18 15:00:00+00:00
# TIW---no longer in universe
# SBO---no longer in universe
# CHE---no longer in universe
# 2002-11-19 15:00:00+00:00
# MDC---no longer in universe
# SBO---no longer in universe
# CHE---no longer in universe
# 2002-11-20 15:00:00+00:00
# SBO---no longer in universe
# 2002-11-21 15:00:00+00:00
# SBO---no longer in universe
# 2002-11-22 15:00:00+00:00
# SBO---no longer in universe
# 2002-11-25 15:00:00+00:00
# PAP---no longer in universe
# JCD---no longer in universe
# SBO---no longer in universe
# 2002-11-26 15:00:00+00:00
# PAP---no longer in universe
# SBO---no longer in universe
# 2002-11-27 15:00:00+00:00
# PAP---no longer in universe
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-11-28 15:00:00+00:00
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-11-29 15:00:00+00:00
# AEN---no longer in universe
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-12-02 15:00:00+00:00
# AEN---no longer in universe
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-12-03 15:00:00+00:00
# SBO---no longer in universe
# UTR---no longer in universe
# CRN---no longer in universe
# 2002-12-04 15:00:00+00:00
# SBO---no longer in universe
# CRN---no longer in universe
# 2002-12-05 15:00:00+00:00
# PAP---no longer in universe
# SBO---no longer in universe
# 2002-12-06 15:00:00+00:00
# SBO---no longer in universe
# 2002-12-09 15:00:00+00:00
# SBO---no longer in universe
# SLU---no longer in universe
# 2002-12-10 15:00:00+00:00
# JCD---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# PMN---no longer in universe
# CRN---no longer in universe
# 2002-12-11 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# PMN---no longer in universe
# CRN---no longer in universe
# 2002-12-12 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# 2002-12-13 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# 2002-12-17 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# 2002-12-18 15:00:00+00:00
# SBO---no longer in universe
# SRL---no longer in universe
# 2002-12-19 15:00:00+00:00
# PON---no longer in universe
# SBO---no longer in universe
# SRL---no longer in universe
# 2002-12-20 15:00:00+00:00
# CPX---no longer in universe
# SBO---no longer in universe
# SRL---no longer in universe
# 2002-12-23 15:00:00+00:00
# CPX---no longer in universe
# SBO---no longer in universe
# MHH---no longer in universe
# SRL---no longer in universe
# 2002-12-24 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# SRL---no longer in universe
# 2002-12-27 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# SRL---no longer in universe
# 2002-12-30 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# SRL---no longer in universe
# 2002-12-31 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# SRL---no longer in universe
# 2003-01-02 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# SRL---no longer in universe
# 2003-01-03 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# SRL---no longer in universe
# 2003-01-06 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# SRL---no longer in universe
# 2003-01-07 15:00:00+00:00
# SBO---no longer in universe
# OMN---no longer in universe
# SRL---no longer in universe
# 2003-01-08 15:00:00+00:00
# SBO---no longer in universe
# OMN---no longer in universe
# SRL---no longer in universe
# 2003-01-09 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# OMN---no longer in universe
# 2003-01-10 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# OMN---no longer in universe
# 2003-01-13 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# OMN---no longer in universe
# SRL---no longer in universe
# 2003-01-14 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# OMN---no longer in universe
# SRL---no longer in universe
# 2003-01-15 15:00:00+00:00
# CPX---no longer in universe
# SBO---no longer in universe
# TDH---no longer in universe
# OMN---no longer in universe
# 2003-01-16 15:00:00+00:00
# CPX---no longer in universe
# SBO---no longer in universe
# TDH---no longer in universe
# OMN---no longer in universe
# 2003-01-17 15:00:00+00:00
# CPX---no longer in universe
# SBO---no longer in universe
# TDH---no longer in universe
# OMN---no longer in universe
# 2003-01-20 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# OMN---no longer in universe
# 2003-01-21 15:00:00+00:00
# SBO---no longer in universe
# TDH---no longer in universe
# OMN---no longer in universe
# 2003-01-22 15:00:00+00:00
# SBO---no longer in universe
# OMN---no longer in universe
# 2003-01-23 15:00:00+00:00
# SBO---no longer in universe
# HCI---no longer in universe
# 2003-01-24 15:00:00+00:00
# SBO---no longer in universe
# HCI---no longer in universe
# 2003-01-27 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# HCI---no longer in universe
# 2003-01-28 15:00:00+00:00
# PPC---no longer in universe
# SBO---no longer in universe
# HCI---no longer in universe
# 2003-01-29 15:00:00+00:00
# PPC---no longer in universe
# SBO---no longer in universe
# HCI---no longer in universe
# 2003-01-30 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-01-31 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# SRL---no longer in universe
# 2003-02-03 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# 2003-02-04 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# SRL---no longer in universe
# 2003-02-05 15:00:00+00:00
# SBO---no longer in universe
# SRL---no longer in universe
# 2003-02-06 15:00:00+00:00
# SBO---no longer in universe
# LBH---no longer in universe
# SRL---no longer in universe
# 2003-02-07 15:00:00+00:00
# PON---no longer in universe
# SBO---no longer in universe
# SRL---no longer in universe
# 2003-02-10 15:00:00+00:00
# SBO---no longer in universe
# 2003-02-11 15:00:00+00:00
# SBO---no longer in universe
# 2003-02-12 15:00:00+00:00
# SBO---no longer in universe
# 2003-02-13 15:00:00+00:00
# TIW---no longer in universe
# SBO---no longer in universe
# 2003-02-14 15:00:00+00:00
# SBO---no longer in universe
# 2003-02-17 15:00:00+00:00
# PEP---no longer in universe
# SBO---no longer in universe
# 2003-02-18 15:00:00+00:00
# TIW---no longer in universe
# PEP---no longer in universe
# SBO---no longer in universe
# 2003-02-19 15:00:00+00:00
# TIW---no longer in universe
# SBO---no longer in universe
# SRL---no longer in universe
# 2003-02-20 15:00:00+00:00
# SBO---no longer in universe
# FSP---no longer in universe
# 2003-02-21 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# FSP---no longer in universe
# 2003-02-24 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# FSP---no longer in universe
# 2003-02-25 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# FSP---no longer in universe
# 2003-02-26 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# FSP---no longer in universe
# 2003-02-27 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# FSP---no longer in universe
# SRL---no longer in universe
# 2003-02-28 15:00:00+00:00
# SBO---no longer in universe
# FSP---no longer in universe
# SRL---no longer in universe
# 2003-03-03 15:00:00+00:00
# SBO---no longer in universe
# FSP---no longer in universe
# SRL---no longer in universe
# 2003-03-04 15:00:00+00:00
# SBO---no longer in universe
# CHE---no longer in universe
# SRL---no longer in universe
# 2003-03-05 15:00:00+00:00
# CPX---no longer in universe
# SBO---no longer in universe
# PMN---no longer in universe
# SRL---no longer in universe
# 2003-03-06 15:00:00+00:00
# SBO---no longer in universe
# PMN---no longer in universe
# SRL---no longer in universe
# 2003-03-07 15:00:00+00:00
# SBO---no longer in universe
# PMN---no longer in universe
# SRL---no longer in universe
# 2003-03-10 15:00:00+00:00
# AFG---no longer in universe
# SBO---no longer in universe
# PMN---no longer in universe
# SRL---no longer in universe
# 2003-03-11 15:00:00+00:00
# AFG---no longer in universe
# SBO---no longer in universe
# PMN---no longer in universe
# SRL---no longer in universe
# 2003-03-12 15:00:00+00:00
# AFG---no longer in universe
# SBO---no longer in universe
# PMN---no longer in universe
# 2003-03-13 15:00:00+00:00
# AFG---no longer in universe
# AEN---no longer in universe
# SBO---no longer in universe
# PMN---no longer in universe
# 2003-03-14 15:00:00+00:00
# AFG---no longer in universe
# AEN---no longer in universe
# SBO---no longer in universe
# PMN---no longer in universe
# 2003-03-17 15:00:00+00:00
# AFG---no longer in universe
# AEN---no longer in universe
# SBO---no longer in universe
# 2003-03-18 15:00:00+00:00
# AFG---no longer in universe
# SNT---no longer in universe
# AEN---no longer in universe
# SBO---no longer in universe
# 2003-03-19 15:00:00+00:00
# AFG---no longer in universe
# AEN---no longer in universe
# SBO---no longer in universe
# CHE---no longer in universe
# 2003-03-20 15:00:00+00:00
# AFG---no longer in universe
# AEN---no longer in universe
# SBO---no longer in universe
# CHE---no longer in universe
# 2003-03-24 15:00:00+00:00
# PGH---no longer in universe
# AEN---no longer in universe
# SBO---no longer in universe
# 2003-03-25 15:00:00+00:00
# AEN---no longer in universe
# SBO---no longer in universe
# 2003-03-26 15:00:00+00:00
# AEN---no longer in universe
# SBO---no longer in universe
# 2003-03-27 15:00:00+00:00
# SBO---no longer in universe
# CHE---no longer in universe
# 2003-03-28 15:00:00+00:00
# SBO---no longer in universe
# 2003-03-31 15:00:00+00:00
# SBO---no longer in universe
# SIS---no longer in universe
# 2003-04-01 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-04-02 15:00:00+00:00
# MRF---no longer in universe
# SBO---no longer in universe
# 2003-04-03 15:00:00+00:00
# AFG---no longer in universe
# SBO---no longer in universe
# 2003-04-04 15:00:00+00:00
# PON---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-04-07 15:00:00+00:00
# AFG---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-04-08 15:00:00+00:00
# MRF---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-04-09 15:00:00+00:00
# MRF---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-04-10 15:00:00+00:00
# MRF---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-04-11 15:00:00+00:00
# PON---no longer in universe
# MRF---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-04-14 15:00:00+00:00
# MRF---no longer in universe
# SBO---no longer in universe
# MTX---no longer in universe
# 2003-04-15 15:00:00+00:00
# MRF---no longer in universe
# SBO---no longer in universe
# MTX---no longer in universe
# 2003-04-16 15:00:00+00:00
# MRF---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# MTX---no longer in universe
# 2003-04-17 15:00:00+00:00
# GRF---no longer in universe
# MRF---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-04-22 15:00:00+00:00
# GRF---no longer in universe
# MRF---no longer in universe
# SBO---no longer in universe
# CHE---no longer in universe
# 2003-04-23 15:00:00+00:00
# GRF---no longer in universe
# MRF---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-04-24 15:00:00+00:00
# GRF---no longer in universe
# MRF---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-04-25 15:00:00+00:00
# GRF---no longer in universe
# MRF---no longer in universe
# SBO---no longer in universe
# 2003-04-29 15:00:00+00:00
# AFR---no longer in universe
# GRF---no longer in universe
# MRF---no longer in universe
# SBO---no longer in universe
# 2003-04-30 15:00:00+00:00
# GRF---no longer in universe
# MRF---no longer in universe
# SBO---no longer in universe
# SYC---no longer in universe
# 2003-05-02 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# SYC---no longer in universe
# 2003-05-05 15:00:00+00:00
# GRF---no longer in universe
# CPX---no longer in universe
# SBO---no longer in universe
# 2003-05-06 15:00:00+00:00
# AFR---no longer in universe
# GRF---no longer in universe
# SBO---no longer in universe
# 2003-05-07 15:00:00+00:00
# AFR---no longer in universe
# GRF---no longer in universe
# SBO---no longer in universe
# 2003-05-08 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# 2003-05-09 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# 2003-05-12 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# 2003-05-13 15:00:00+00:00
# GRF---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-05-14 15:00:00+00:00
# MDC---no longer in universe
# GRF---no longer in universe
# SBO---no longer in universe
# 2003-05-15 15:00:00+00:00
# MDC---no longer in universe
# SBO---no longer in universe
# 2003-05-16 15:00:00+00:00
# MDC---no longer in universe
# SBO---no longer in universe
# 2003-05-19 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-05-20 15:00:00+00:00
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-05-21 15:00:00+00:00
# DSY---no longer in universe
# SBO---no longer in universe
# MRP---no longer in universe
# 2003-05-22 15:00:00+00:00
# DSY---no longer in universe
# SBO---no longer in universe
# 2003-05-23 15:00:00+00:00
# AFG---no longer in universe
# SNT---no longer in universe
# SBO---no longer in universe
# 2003-05-26 15:00:00+00:00
# AFG---no longer in universe
# SNT---no longer in universe
# SBO---no longer in universe
# 2003-05-27 15:00:00+00:00
# AFG---no longer in universe
# ENR---no longer in universe
# SBO---no longer in universe
# 2003-05-28 15:00:00+00:00
# AFG---no longer in universe
# SBO---no longer in universe
# 2003-05-29 15:00:00+00:00
# AFG---no longer in universe
# SBO---no longer in universe
# 2003-05-30 15:00:00+00:00
# AFG---no longer in universe
# SBO---no longer in universe
# 2003-06-02 15:00:00+00:00
# AFG---no longer in universe
# SBO---no longer in universe
# 2003-06-03 15:00:00+00:00
# AFG---no longer in universe
# SBO---no longer in universe
# 2003-06-04 15:00:00+00:00
# AFG---no longer in universe
# SBO---no longer in universe
# 2003-06-05 15:00:00+00:00
# AFG---no longer in universe
# DTC---no longer in universe
# SBO---no longer in universe
# 2003-06-06 15:00:00+00:00
# AFG---no longer in universe
# DTC---no longer in universe
# SBO---no longer in universe
# 2003-06-09 15:00:00+00:00
# AFG---no longer in universe
# CEN---no longer in universe
# DTC---no longer in universe
# SBO---no longer in universe
# APB---no longer in universe
# MPL---no longer in universe
# 2003-06-10 15:00:00+00:00
# AFG---no longer in universe
# CEN---no longer in universe
# SBO---no longer in universe
# APB---no longer in universe
# MPL---no longer in universe
# 2003-06-11 15:00:00+00:00
# AFG---no longer in universe
# CEN---no longer in universe
# SBO---no longer in universe
# APB---no longer in universe
# MRP---no longer in universe
# MPL---no longer in universe
# 2003-06-12 15:00:00+00:00
# AFG---no longer in universe
# CEN---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-06-13 15:00:00+00:00
# AFG---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-06-17 15:00:00+00:00
# AFG---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# PSG---no longer in universe
# 2003-06-18 15:00:00+00:00
# AFG---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# PSG---no longer in universe
# 2003-06-19 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# PSG---no longer in universe
# 2003-06-20 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# PSG---no longer in universe
# 2003-06-23 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-06-24 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-06-25 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-06-26 15:00:00+00:00
# CEN---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-06-27 15:00:00+00:00
# CEN---no longer in universe
# ENR---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-06-30 15:00:00+00:00
# CEN---no longer in universe
# ENR---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# AHV---no longer in universe
# 2003-07-01 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# ENR---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# 2003-07-02 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-07-03 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-07-04 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-07-07 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-07-08 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# LBH---no longer in universe
# 2003-07-09 15:00:00+00:00
# CEN---no longer in universe
# AEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# HYP---no longer in universe
# 2003-07-10 15:00:00+00:00
# CEN---no longer in universe
# AEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# LBH---no longer in universe
# HYP---no longer in universe
# 2003-07-11 15:00:00+00:00
# CEN---no longer in universe
# AEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# LBH---no longer in universe
# PSG---no longer in universe
# HYP---no longer in universe
# 2003-07-14 15:00:00+00:00
# CEN---no longer in universe
# AEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# LBH---no longer in universe
# PSG---no longer in universe
# HYP---no longer in universe
# 2003-07-15 15:00:00+00:00
# CEN---no longer in universe
# AEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# LBH---no longer in universe
# HYP---no longer in universe
# 2003-07-16 15:00:00+00:00
# CEN---no longer in universe
# AEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# LBH---no longer in universe
# HYP---no longer in universe
# 2003-07-17 15:00:00+00:00
# CEN---no longer in universe
# ENR---no longer in universe
# AEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# LBH---no longer in universe
# HYP---no longer in universe
# 2003-07-18 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# LBH---no longer in universe
# HYP---no longer in universe
# 2003-07-21 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# LBH---no longer in universe
# HYP---no longer in universe
# 2003-07-22 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# HYP---no longer in universe
# 2003-07-23 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# HYP---no longer in universe
# 2003-07-24 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-07-25 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-07-28 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-07-29 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-07-30 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-07-31 15:00:00+00:00
# RES---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# 2003-08-01 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-08-04 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-08-05 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-08-06 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-08-07 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-08-08 15:00:00+00:00
# CEN---no longer in universe
# CPX---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-08-11 15:00:00+00:00
# CEN---no longer in universe
# CPX---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-08-12 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-08-13 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-08-14 15:00:00+00:00
# CEN---no longer in universe
# AEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-08-15 15:00:00+00:00
# CEN---no longer in universe
# AEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-08-18 15:00:00+00:00
# PMG---no longer in universe
# CEN---no longer in universe
# AEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-08-19 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# AEN---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-08-20 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# AEN---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-08-21 15:00:00+00:00
# RES---no longer in universe
# CEN---no longer in universe
# AEN---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-08-22 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-08-25 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-08-26 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# PSG---no longer in universe
# 2003-08-27 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# 2003-08-28 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# CHE---no longer in universe
# 2003-08-29 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# CHE---no longer in universe
# 2003-09-01 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# CHE---no longer in universe
# 2003-09-02 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# CHE---no longer in universe
# 2003-09-03 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# CHE---no longer in universe
# 2003-09-04 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# 2003-09-05 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# 2003-09-08 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# 2003-09-09 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# 2003-09-10 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# DTC---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# 2003-09-11 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# 2003-09-12 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# SYC---no longer in universe
# 2003-09-15 15:00:00+00:00
# AOD---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# SYC---no longer in universe
# 2003-09-16 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# SYC---no longer in universe
# 2003-09-17 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# SYC---no longer in universe
# 2003-09-18 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# SYC---no longer in universe
# 2003-09-19 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# SYC---no longer in universe
# 2003-09-22 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# 2003-09-23 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-09-25 15:00:00+00:00
# MDC---no longer in universe
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-09-26 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-09-29 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-09-30 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-01 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-02 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-03 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-06 15:00:00+00:00
# CEN---no longer in universe
# PRM---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-07 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-08 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-09 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-10 15:00:00+00:00
# CEN---no longer in universe
# DTC---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-13 15:00:00+00:00
# CEN---no longer in universe
# DTC---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-14 15:00:00+00:00
# CEN---no longer in universe
# DTC---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-15 15:00:00+00:00
# CEN---no longer in universe
# DTC---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-16 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# CHE---no longer in universe
# 2003-10-17 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# CHE---no longer in universe
# 2003-10-20 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# AMB---no longer in universe
# ING---no longer in universe
# CHE---no longer in universe
# WET---no longer in universe
# 2003-10-21 15:00:00+00:00
# CEN---no longer in universe
# RCL---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# CHE---no longer in universe
# 2003-10-22 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-23 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# ING---no longer in universe
# 2003-10-24 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# TRE---no longer in universe
# 2003-10-27 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# TRE---no longer in universe
# 2003-10-28 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# TRE---no longer in universe
# 2003-10-29 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# TRE---no longer in universe
# 2003-10-30 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# TRE---no longer in universe
# 2003-10-31 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# TRE---no longer in universe
# 2003-11-03 15:00:00+00:00
# CEN---no longer in universe
# SBO---no longer in universe
# TRE---no longer in universe
# ...
# 2016-09-16 15:00:00+00:00
# AXL---no longer in universe
# 2016-09-19 15:00:00+00:00
# AXL---no longer in universe
# 2016-09-20 15:00:00+00:00
# AXL---no longer in universe
# 2016-09-21 15:00:00+00:00
# AXL---no longer in universe
# COH---no longer in universe
# 2016-09-22 15:00:00+00:00
# AXL---no longer in universe
# 2016-09-23 15:00:00+00:00
# AXL---no longer in universe
# 2016-09-26 15:00:00+00:00
# AXL---no longer in universe
# 2016-09-27 15:00:00+00:00
# AXL---no longer in universe
# 2016-09-28 15:00:00+00:00
# AXL---no longer in universe
# 2016-09-29 15:00:00+00:00
# AXL---no longer in universe
# 2016-09-30 15:00:00+00:00
# AXL---no longer in universe
# SAB---no longer in universe
# 2016-10-03 15:00:00+00:00
# AXL---no longer in universe
# ARL---no longer in universe
# 2016-10-04 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-05 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-06 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-07 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-10 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-11 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-12 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-13 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-14 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-17 15:00:00+00:00
# AXL---no longer in universe
# ADH---no longer in universe
# 2016-10-18 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-19 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-20 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-21 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-24 15:00:00+00:00
# AXL---no longer in universe
# MPT---no longer in universe
# 2016-10-25 15:00:00+00:00
# AXL---no longer in universe
# MPT---no longer in universe
# 2016-10-26 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-27 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-28 15:00:00+00:00
# AXL---no longer in universe
# 2016-10-31 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-01 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-02 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-03 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-04 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-07 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-08 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-09 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-10 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-11 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-14 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-15 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-16 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-17 15:00:00+00:00
# AXL---no longer in universe
# COH---no longer in universe
# 2016-11-18 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-21 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-22 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-23 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-24 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-25 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-28 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-29 15:00:00+00:00
# AXL---no longer in universe
# 2016-11-30 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-01 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-02 15:00:00+00:00
# AXL---no longer in universe
# KAP---no longer in universe
# 2016-12-05 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-06 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-07 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-08 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-09 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-12 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-13 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-14 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-15 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-19 15:00:00+00:00
# AXL---no longer in universe
# EMI---no longer in universe
# 2016-12-20 15:00:00+00:00
# AXL---no longer in universe
# KAP---no longer in universe
# 2016-12-21 15:00:00+00:00
# AXL---no longer in universe
# KAP---no longer in universe
# 2016-12-22 15:00:00+00:00
# AXL---no longer in universe
# LON---no longer in universe
# 2016-12-23 15:00:00+00:00
# AXL---no longer in universe
# LON---no longer in universe
# 2016-12-28 15:00:00+00:00
# AXL---no longer in universe
# KAP---no longer in universe
# LON---no longer in universe
# 2016-12-29 15:00:00+00:00
# AXL---no longer in universe
# 2016-12-30 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-03 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-04 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-05 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-06 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-09 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-10 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-11 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-12 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-13 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-16 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-17 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-18 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-19 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-20 15:00:00+00:00
# SNT---no longer in universe
# AXL---no longer in universe
# 2017-01-23 15:00:00+00:00
# AXL---no longer in universe
# GND---no longer in universe
# 2017-01-24 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-25 15:00:00+00:00
# AXL---no longer in universe
# PGR---no longer in universe
# 2017-01-26 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-27 15:00:00+00:00
# AXL---no longer in universe
# 2017-01-30 15:00:00+00:00
# SNT---no longer in universe
# AXL---no longer in universe
# 2017-01-31 15:00:00+00:00
# AXL---no longer in universe
# PGR---no longer in universe
# 2017-02-01 15:00:00+00:00
# SNT---no longer in universe
# AXL---no longer in universe
# 2017-02-02 15:00:00+00:00
# VKE---no longer in universe
# 2017-02-03 15:00:00+00:00
# 2017-02-06 15:00:00+00:00
# 2017-02-07 15:00:00+00:00
# 2017-02-08 15:00:00+00:00
# 2017-02-09 15:00:00+00:00
# 2017-02-10 15:00:00+00:00
# 2017-02-13 15:00:00+00:00
# PGR---no longer in universe
# 2017-02-14 15:00:00+00:00
# 2017-02-15 15:00:00+00:00
# 2017-02-16 15:00:00+00:00
# VKE---no longer in universe
# 2017-02-17 15:00:00+00:00
# SNT---no longer in universe
# 2017-02-20 15:00:00+00:00
# 2017-02-21 15:00:00+00:00
# 2017-02-22 15:00:00+00:00
# 2017-02-23 15:00:00+00:00
# 2017-02-24 15:00:00+00:00
# 2017-02-27 15:00:00+00:00
# 2017-02-28 15:00:00+00:00
# 2017-03-01 15:00:00+00:00
# 2017-03-02 15:00:00+00:00
# 2017-03-03 15:00:00+00:00
# 2017-03-06 15:00:00+00:00
# 2017-03-07 15:00:00+00:00
# 2017-03-08 15:00:00+00:00
# 2017-03-09 15:00:00+00:00
# 2017-03-10 15:00:00+00:00
# 2017-03-13 15:00:00+00:00
# 2017-03-14 15:00:00+00:00
# 2017-03-15 15:00:00+00:00
# 2017-03-16 15:00:00+00:00
# 2017-03-17 15:00:00+00:00
# 2017-03-20 15:00:00+00:00
# 2017-03-22 15:00:00+00:00
# 2017-03-23 15:00:00+00:00
# 2017-03-24 15:00:00+00:00
# 2017-03-27 15:00:00+00:00
# 2017-03-28 15:00:00+00:00
# 2017-03-29 15:00:00+00:00
# 2017-03-30 15:00:00+00:00
# 2017-03-31 15:00:00+00:00
# 2017-04-03 15:00:00+00:00
# 2017-04-04 15:00:00+00:00
# 2017-04-05 15:00:00+00:00
# RPL---no longer in universe
# 2017-04-06 15:00:00+00:00
# ASR---no longer in universe
# 2017-04-07 15:00:00+00:00
# PGR---no longer in universe
# 2017-04-10 15:00:00+00:00
# 2017-04-11 15:00:00+00:00
# 2017-04-12 15:00:00+00:00
# 2017-04-13 15:00:00+00:00
# 2017-04-18 15:00:00+00:00
# 2017-04-19 15:00:00+00:00
# 2017-04-20 15:00:00+00:00
# 2017-04-21 15:00:00+00:00
# 2017-04-24 15:00:00+00:00
# 2017-04-25 15:00:00+00:00
# 2017-04-26 15:00:00+00:00
# 2017-04-28 15:00:00+00:00
# WBO---no longer in universe
# 2017-05-02 15:00:00+00:00
# 2017-05-03 15:00:00+00:00
# 2017-05-04 15:00:00+00:00
# 2017-05-05 15:00:00+00:00
# 2017-05-08 15:00:00+00:00
# 2017-05-09 15:00:00+00:00
# 2017-05-10 15:00:00+00:00
# 2017-05-11 15:00:00+00:00
# 2017-05-12 15:00:00+00:00
# 2017-05-15 15:00:00+00:00
# 2017-05-16 15:00:00+00:00
# 2017-05-17 15:00:00+00:00
# 2017-05-18 15:00:00+00:00
# 2017-05-19 15:00:00+00:00
# ASR---no longer in universe
# 2017-05-22 15:00:00+00:00
# 2017-05-23 15:00:00+00:00
# AWA---no longer in universe
# 2017-05-24 15:00:00+00:00
# 2017-05-25 15:00:00+00:00
# 2017-05-26 15:00:00+00:00
# ASR---no longer in universe
# 2017-05-29 15:00:00+00:00
# 2017-05-30 15:00:00+00:00
# 2017-05-31 15:00:00+00:00
# 2017-06-01 15:00:00+00:00
# 2017-06-02 15:00:00+00:00
# 2017-06-05 15:00:00+00:00
# 2017-06-06 15:00:00+00:00
# 2017-06-07 15:00:00+00:00
# 2017-06-08 15:00:00+00:00
# OMN---no longer in universe
# 2017-06-09 15:00:00+00:00
# 2017-06-12 15:00:00+00:00
# 2017-06-13 15:00:00+00:00
# 2017-06-14 15:00:00+00:00
# 2017-06-15 15:00:00+00:00
# 2017-06-19 15:00:00+00:00
# 2017-06-20 15:00:00+00:00
# SAC---no longer in universe
# 2017-06-21 15:00:00+00:00
# 2017-06-22 15:00:00+00:00
# AFH---no longer in universe
# 2017-06-23 15:00:00+00:00
# AFH---no longer in universe
# 2017-06-26 15:00:00+00:00
# 2017-06-27 15:00:00+00:00
# 2017-06-28 15:00:00+00:00
# 2017-06-29 15:00:00+00:00
# 2017-06-30 15:00:00+00:00
# 2017-07-03 15:00:00+00:00
# 2017-07-04 15:00:00+00:00
# 2017-07-05 15:00:00+00:00
# AWA---no longer in universe
# 2017-07-06 15:00:00+00:00
# 2017-07-07 15:00:00+00:00
# 2017-07-10 15:00:00+00:00
# OMN---no longer in universe
# 2017-07-11 15:00:00+00:00
# 2017-07-12 15:00:00+00:00
# NEP---no longer in universe
# ROC---no longer in universe
# 2017-07-13 15:00:00+00:00
# 2017-07-14 15:00:00+00:00
# 2017-07-17 15:00:00+00:00
# 2017-07-18 15:00:00+00:00
# 2017-07-19 15:00:00+00:00
# 2017-07-20 15:00:00+00:00
# 2017-07-21 15:00:00+00:00
# OMN---no longer in universe
# 2017-07-24 15:00:00+00:00
# 2017-07-25 15:00:00+00:00
# 2017-07-26 15:00:00+00:00
# 2017-07-27 15:00:00+00:00
# 2017-07-28 15:00:00+00:00
# 2017-07-31 15:00:00+00:00
# 2017-08-01 15:00:00+00:00
# 2017-08-02 15:00:00+00:00
# ASC---no longer in universe
# 2017-08-03 15:00:00+00:00
# ASC---no longer in universe
# 2017-08-04 15:00:00+00:00
# 2017-08-07 15:00:00+00:00
# 2017-08-08 15:00:00+00:00
# 2017-08-10 15:00:00+00:00
# 2017-08-11 15:00:00+00:00
# 2017-08-14 15:00:00+00:00
# 2017-08-15 15:00:00+00:00
# MUR---no longer in universe
# 2017-08-16 15:00:00+00:00
# 2017-08-17 15:00:00+00:00
# 2017-08-18 15:00:00+00:00
# 2017-08-21 15:00:00+00:00
# OMN---no longer in universe
# 2017-08-22 15:00:00+00:00
# 2017-08-23 15:00:00+00:00
# ASC---no longer in universe
# 2017-08-24 15:00:00+00:00
# 2017-08-25 15:00:00+00:00
# 2017-08-28 15:00:00+00:00
# SNT---no longer in universe
# 2017-08-29 15:00:00+00:00
# ASC---no longer in universe
# 2017-08-30 15:00:00+00:00
# SNT---no longer in universe
# 2017-08-31 15:00:00+00:00
# ASC---no longer in universe
# 2017-09-01 15:00:00+00:00
# 2017-09-04 15:00:00+00:00
# ADH---no longer in universe
# 2017-09-05 15:00:00+00:00
# 2017-09-06 15:00:00+00:00
# ASC---no longer in universe
# 2017-09-07 15:00:00+00:00
# ASC---no longer in universe
# 2017-09-08 15:00:00+00:00
# 2017-09-11 15:00:00+00:00
# DST---no longer in universe
# 2017-09-12 15:00:00+00:00
# 2017-09-13 15:00:00+00:00
# SUI---no longer in universe
# 2017-09-14 15:00:00+00:00
# 2017-09-15 15:00:00+00:00
# 2017-09-18 15:00:00+00:00
# 2017-09-19 15:00:00+00:00
# AFH---no longer in universe
# 2017-09-20 15:00:00+00:00
# AWA---no longer in universe
# 2017-09-21 15:00:00+00:00
# 2017-09-22 15:00:00+00:00
# AFH---no longer in universe
# 2017-09-26 15:00:00+00:00
# AFH---no longer in universe
# 2017-09-27 15:00:00+00:00
# 2017-09-28 15:00:00+00:00
# 2017-09-29 15:00:00+00:00
# 2017-10-02 15:00:00+00:00
# 2017-10-03 15:00:00+00:00
# 2017-10-04 15:00:00+00:00
# 2017-10-05 15:00:00+00:00
# 2017-10-06 15:00:00+00:00
# 2017-10-09 15:00:00+00:00
# SNT---no longer in universe
# 2017-10-10 15:00:00+00:00
# 2017-10-11 15:00:00+00:00
# 2017-10-12 15:00:00+00:00
# AFH---no longer in universe
# 2017-10-13 15:00:00+00:00
# 2017-10-16 15:00:00+00:00
# 2017-10-17 15:00:00+00:00
# 2017-10-18 15:00:00+00:00
# 2017-10-19 15:00:00+00:00
# 2017-10-20 15:00:00+00:00
# SNT---no longer in universe
# 2017-10-23 15:00:00+00:00
# AFH---no longer in universe
# 2017-10-24 15:00:00+00:00
# 2017-10-25 15:00:00+00:00
# 2017-10-26 15:00:00+00:00
# 2017-10-27 15:00:00+00:00
# ASR---no longer in universe
# 2017-10-30 15:00:00+00:00
# 2017-10-31 15:00:00+00:00
# 2017-11-01 15:00:00+00:00
# EQU---no longer in universe
# 2017-11-02 15:00:00+00:00
# 2017-11-03 15:00:00+00:00
# 2017-11-06 15:00:00+00:00
# 2017-11-07 15:00:00+00:00
# 2017-11-08 15:00:00+00:00
# OMN---no longer in universe
# 2017-11-09 15:00:00+00:00
# OMN---no longer in universe
# 2017-11-10 15:00:00+00:00
# 2017-11-13 15:00:00+00:00
# 2017-11-14 15:00:00+00:00
# 2017-11-15 15:00:00+00:00
# 2017-11-16 15:00:00+00:00
# 2017-11-17 15:00:00+00:00
# 2017-11-20 15:00:00+00:00
# 2017-11-21 15:00:00+00:00
# 2017-11-22 15:00:00+00:00
# 2017-11-23 15:00:00+00:00
# 2017-11-24 15:00:00+00:00
# 2017-11-27 15:00:00+00:00
# 2017-11-28 15:00:00+00:00
# 2017-11-29 15:00:00+00:00
# REI---no longer in universe
# 2017-11-30 15:00:00+00:00
# 2017-12-01 15:00:00+00:00
# 2017-12-04 15:00:00+00:00
# 2017-12-05 15:00:00+00:00
# 2017-12-06 15:00:00+00:00
# 2017-12-07 15:00:00+00:00
# 2017-12-08 15:00:00+00:00
# 2017-12-11 15:00:00+00:00
# 2017-12-12 15:00:00+00:00
# 2017-12-13 15:00:00+00:00
# 2017-12-14 15:00:00+00:00
# 2017-12-15 15:00:00+00:00
# 2017-12-18 15:00:00+00:00
# EPP---no longer in universe
# OMN---no longer in universe
# 2017-12-19 15:00:00+00:00
# 2017-12-20 15:00:00+00:00
# 2017-12-21 15:00:00+00:00
# 2017-12-22 15:00:00+00:00
# COH---no longer in universe
# 2017-12-27 15:00:00+00:00
# 2017-12-28 15:00:00+00:00
# AWA---no longer in universe
# 2017-12-29 15:00:00+00:00
# COH---no longer in universe
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /Users/evanfotopoulos/Projects/EquityBacktest/src/backtester.py:43
#      30 pricing_loader = PricingLoader(bundle_data)
#      32 result = run_algorithm(
#      33     start=start,  # Set start
#      34     end=end,  # Set end
#    (...)
#      40     custom_loader=pricing_loader,
#      41 )
# ---> 43 result.to_pickle(create_output_path("backtest.pkl"))
#      44 print("Ready to analyze result")
#
# File ~/Projects/EquityBacktest/.venv/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Projects/EquityBacktest/.venv/lib/python3.11/site-packages/pandas/core/generic.py:3165, in NDFrame.to_pickle(self, path, compression, protocol, storage_options)
#    3115 """
#    3116 Pickle (serialize) object to file.
#    3117
#    (...)
#    3161 4    4    9
#    3162 """  # noqa: E501
#    3163 from pandas.io.pickle import to_pickle
# -> 3165 to_pickle(
#    3166     self,
#    3167     path,
#    3168     compression=compression,
#    3169     protocol=protocol,
#    3170     storage_options=storage_options,
#    3171 )
#
# File ~/Projects/EquityBacktest/.venv/lib/python3.11/site-packages/pandas/io/pickle.py:103, in to_pickle(obj, filepath_or_buffer, compression, protocol, storage_options)
#     100 if protocol < 0:
#     101     protocol = pickle.HIGHEST_PROTOCOL
# --> 103 with get_handle(
#     104     filepath_or_buffer,
#     105     "wb",
#     106     compression=compression,
#     107     is_text=False,
#     108     storage_options=storage_options,
#     109 ) as handles:
#     110     # letting pickle write directly to the buffer is more memory-efficient
#     111     pickle.dump(obj, handles.handle, protocol=protocol)
#
# File ~/Projects/EquityBacktest/.venv/lib/python3.11/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/Projects/EquityBacktest/.venv/lib/python3.11/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'examples'

# %% [markdown]
# Need to fix the output path

# %%
output_path = "../examples/"

# %%
path = output_path

# %%
def create_output_path(
    file_name: str, path: str = path, run_time: str = run_time
) -> str:
    return "".join([path, run_time, "_", file_name])

# %%
result.to_pickle(create_output_path("backtest.pkl"))

# %% [markdown]
# Create a benchmark from a listed Top40 index tracker

# %%
# %%

# Create a benchmark dataframe
def create_benchmark(fname):
    bench = pd.read_csv(
        "{}.csv".format(fname),
        index_col="Date",
        parse_dates=True,
    )
    bench_series = pd.Series(bench["return"].values, index=bench.index)
    bench_series.rename(fname, inplace=True)
    return bench_series


bench_series = create_benchmark("../STX40")

# %% [markdown]
# Add benchmark to results and save some backtest related outputs to the output path

# %%
# %%

result.index = result.index.normalize()  # to set the time to 00:00:00
bench_series = bench_series[
    bench_series.index.isin(result.index.tz_localize(None))
].tz_localize("UTC")

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(result)

returns_table = pf.create_simple_tear_sheet(returns, benchmark_rets=bench_series)
returns_table.to_csv(create_output_path("returns_table.csv"))
plt.savefig(create_output_path("returns_tear_sheet.png"), bbox_inches="tight")
plt.close()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2002-01-07</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2017-12-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>190</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>13.76%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>672.372%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>5.631%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.32</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.57</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.081%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.50</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.57</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.27</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>5.28</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.21</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.658%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.14</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The backtest has now been run and the raw outputs have been saved as a pickle file to the "examples/" folder. These results can be pointed at by the backtest_analyser script to perform further analysis. These results are net of transaction costs
