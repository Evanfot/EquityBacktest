# %% [markdown]
# # Code used to generate tearsheets for a given backtest result

# %%
# %%

import sys

sys.path.append("..")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pyfolio as pf
from pyfolio.plotting import show_perf_stats

file_path = (
    "/Users/evanfotopoulos/Projects/EquityBacktest/examples/20240530_1400_backtest.pkl"
)
result = pd.read_pickle(file_path)


returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(result)
perf_stats = show_perf_stats(returns, positions=positions, transactions=transactions)

pf.create_full_tear_sheet(returns, positions, transactions)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2002-01-07</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2017-12-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>190</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>13.76%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>672.372%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>5.631%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.32</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.57</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.081%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.50</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.57</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.27</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>5.28</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.21</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.658%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>43.275%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2002-01-07</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2017-12-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>190</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>13.76%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>672.372%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>5.631%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.32</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.57</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.081%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.50</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.57</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.27</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>5.28</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.21</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.658%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>43.275%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24.08</td>
#       <td>2015-11-17</td>
#       <td>2017-04-18</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>7.17</td>
#       <td>2009-02-09</td>
#       <td>2009-06-11</td>
#       <td>2010-01-05</td>
#       <td>237</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.22</td>
#       <td>2015-04-13</td>
#       <td>2015-08-24</td>
#       <td>2015-10-26</td>
#       <td>141</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.88</td>
#       <td>2008-08-29</td>
#       <td>2008-10-27</td>
#       <td>2008-12-04</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.46</td>
#       <td>2003-12-31</td>
#       <td>2004-01-16</td>
#       <td>2004-02-02</td>
#       <td>24</td>
#     </tr>
#   </tbody>
# </table>
# /Users/evanfotopoulos/Projects/EquityBacktest/.venv/lib/python3.11/site-packages/pyfolio/plotting.py:1375: UserWarning: The palette list has more values (3) than needed (1), which may not be intended.
#   sns.boxplot(
# /Users/evanfotopoulos/Projects/EquityBacktest/.venv/lib/python3.11/site-packages/pyfolio/plotting.py:1403: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Daily", "Weekly", "Monthly"])
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Lehman</th>
#       <td>-0.06%</td>
#       <td>-1.12%</td>
#       <td>1.10%</td>
#     </tr>
#     <tr>
#       <th>US downgrade/European Debt Crisis</th>
#       <td>0.10%</td>
#       <td>-0.68%</td>
#       <td>0.90%</td>
#     </tr>
#     <tr>
#       <th>Fukushima</th>
#       <td>0.06%</td>
#       <td>-0.29%</td>
#       <td>0.70%</td>
#     </tr>
#     <tr>
#       <th>US Housing</th>
#       <td>0.08%</td>
#       <td>-0.80%</td>
#       <td>0.81%</td>
#     </tr>
#     <tr>
#       <th>EZB IR Event</th>
#       <td>0.07%</td>
#       <td>-0.83%</td>
#       <td>0.69%</td>
#     </tr>
#     <tr>
#       <th>Aug07</th>
#       <td>0.10%</td>
#       <td>-0.64%</td>
#       <td>1.08%</td>
#     </tr>
#     <tr>
#       <th>Mar08</th>
#       <td>0.18%</td>
#       <td>-0.56%</td>
#       <td>0.70%</td>
#     </tr>
#     <tr>
#       <th>Sept08</th>
#       <td>-0.16%</td>
#       <td>-1.12%</td>
#       <td>0.95%</td>
#     </tr>
#     <tr>
#       <th>2009Q1</th>
#       <td>0.14%</td>
#       <td>-0.99%</td>
#       <td>1.20%</td>
#     </tr>
#     <tr>
#       <th>2009Q2</th>
#       <td>-0.05%</td>
#       <td>-1.76%</td>
#       <td>2.06%</td>
#     </tr>
#     <tr>
#       <th>Flash Crash</th>
#       <td>0.11%</td>
#       <td>-1.06%</td>
#       <td>1.42%</td>
#     </tr>
#     <tr>
#       <th>Apr14</th>
#       <td>0.04%</td>
#       <td>-0.26%</td>
#       <td>0.54%</td>
#     </tr>
#     <tr>
#       <th>Oct14</th>
#       <td>0.04%</td>
#       <td>-0.38%</td>
#       <td>0.80%</td>
#     </tr>
#     <tr>
#       <th>Fall2015</th>
#       <td>0.07%</td>
#       <td>-1.00%</td>
#       <td>1.59%</td>
#     </tr>
#     <tr>
#       <th>Low Volatility Bull Market</th>
#       <td>0.07%</td>
#       <td>-0.99%</td>
#       <td>0.99%</td>
#     </tr>
#     <tr>
#       <th>GFC Crash</th>
#       <td>0.09%</td>
#       <td>-2.47%</td>
#       <td>2.01%</td>
#     </tr>
#     <tr>
#       <th>Recovery</th>
#       <td>0.03%</td>
#       <td>-1.36%</td>
#       <td>2.06%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.01%</td>
#       <td>-2.79%</td>
#       <td>2.00%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>WEZ</th>
#       <td>5.05%</td>
#     </tr>
#     <tr>
#       <th>KIO</th>
#       <td>4.95%</td>
#     </tr>
#     <tr>
#       <th>SGL</th>
#       <td>4.87%</td>
#     </tr>
#     <tr>
#       <th>SIM</th>
#       <td>4.81%</td>
#     </tr>
#     <tr>
#       <th>ASR</th>
#       <td>4.73%</td>
#     </tr>
#     <tr>
#       <th>ACL</th>
#       <td>4.72%</td>
#     </tr>
#     <tr>
#       <th>MUR</th>
#       <td>4.68%</td>
#     </tr>
#     <tr>
#       <th>EOH</th>
#       <td>4.61%</td>
#     </tr>
#     <tr>
#       <th>AFL</th>
#       <td>4.59%</td>
#     </tr>
#     <tr>
#       <th>ARI</th>
#       <td>4.58%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AIP</th>
#       <td>-4.90%</td>
#     </tr>
#     <tr>
#       <th>SHP</th>
#       <td>-4.90%</td>
#     </tr>
#     <tr>
#       <th>LON</th>
#       <td>-4.84%</td>
#     </tr>
#     <tr>
#       <th>IMP</th>
#       <td>-4.81%</td>
#     </tr>
#     <tr>
#       <th>MUR</th>
#       <td>-4.76%</td>
#     </tr>
#     <tr>
#       <th>MTX</th>
#       <td>-4.73%</td>
#     </tr>
#     <tr>
#       <th>WEZ</th>
#       <td>-4.72%</td>
#     </tr>
#     <tr>
#       <th>WAR</th>
#       <td>-4.65%</td>
#     </tr>
#     <tr>
#       <th>SAP</th>
#       <td>-4.62%</td>
#     </tr>
#     <tr>
#       <th>ASR</th>
#       <td>-4.55%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>WEZ</th>
#       <td>5.05%</td>
#     </tr>
#     <tr>
#       <th>KIO</th>
#       <td>4.95%</td>
#     </tr>
#     <tr>
#       <th>AIP</th>
#       <td>4.90%</td>
#     </tr>
#     <tr>
#       <th>SHP</th>
#       <td>4.90%</td>
#     </tr>
#     <tr>
#       <th>SGL</th>
#       <td>4.87%</td>
#     </tr>
#     <tr>
#       <th>LON</th>
#       <td>4.84%</td>
#     </tr>
#     <tr>
#       <th>SIM</th>
#       <td>4.81%</td>
#     </tr>
#     <tr>
#       <th>IMP</th>
#       <td>4.81%</td>
#     </tr>
#     <tr>
#       <th>MUR</th>
#       <td>4.76%</td>
#     </tr>
#     <tr>
#       <th>MTX</th>
#       <td>4.73%</td>
#     </tr>
#   </tbody>
# </table>
# /Users/evanfotopoulos/Projects/EquityBacktest/.venv/lib/python3.11/site-packages/pyfolio/pos.py:100: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   longs = expos.where(expos.applymap(lambda x: x > 0))
# /Users/evanfotopoulos/Projects/EquityBacktest/.venv/lib/python3.11/site-packages/pyfolio/pos.py:101: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   shorts = expos.where(expos.applymap(lambda x: x < 0))
